# %% [markdown]
# # What if my dataset isn't on the Hub?

# %% [markdown]
# Install the Transformers and Datasets libraries to run this notebook.

# %%
# !pip install datasets transformers sentencepiece -qqq
# Out:
#      |████████████████████████████████| 298 kB 31.5 MB/s
#      |████████████████████████████████| 3.1 MB 41.2 MB/s
#      |████████████████████████████████| 1.2 MB 48.4 MB/s
#      |████████████████████████████████| 243 kB 61.3 MB/s
#      |████████████████████████████████| 132 kB 57.1 MB/s
#      |████████████████████████████████| 1.1 MB 60.0 MB/s
#      |████████████████████████████████| 59 kB 7.3 MB/s
#      |████████████████████████████████| 3.3 MB 47.5 MB/s
#      |████████████████████████████████| 895 kB 30.3 MB/s
#      |████████████████████████████████| 596 kB 67.5 MB/s
#      |████████████████████████████████| 160 kB 66.4 MB/s
#      |████████████████████████████████| 271 kB 61.7 MB/s
#      |████████████████████████████████| 192 kB 63.0 MB/s

# %% [markdown]
# ## Loading a local dataset

# %%
# %%capture
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz

# %%
# !gzip -dkv SQuAD_it-*.json.gz
# Out:
# SQuAD_it-test.json.gz:	 87.5% -- replaced with SQuAD_it-test.json
# SQuAD_it-train.json.gz:	 82.3% -- replaced with SQuAD_it-train.json

# %%
from datasets import load_dataset

squad_it_dataset = load_dataset("json", data_files="SQuAD_it-train.json", field="data")
# Out:
# Using custom data configuration default-3ef5906a7be178e8
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-3ef5906a7be178e8/0.0.0/c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
# })

# %%
squad_it_dataset["train"][0]
# Out:
# {'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#     {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
#      'id': '56d4f9902ccc5a1400d833c1',
# ...

# %%
data_files = {"train": "SQuAD_it-train.json", "test": "SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
squad_it_dataset
# Out:
# Using custom data configuration default-69caf8dfef498982
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-69caf8dfef498982/0.0.0/c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
print(squad_it_dataset['train'][0])
# Out:
# {'title': 'Terremoto del Sichuan del 2008', 'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.", 'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}], 'id': '56cdca7862d2951400fa6826', 'question': 'In quale anno si è verificato il terremoto nel Sichuan?'}, {'answers': [{'answer_start': 232, 'text': '69.197'}], 'id': '56cdca7862d2951400fa6828', 'question': 'Quante persone sono state uccise come risultato?'}, {'answers': [{'answer_start': 29, 'text': '2008'}], 'id': '56d4f9902ccc5a1400d833c0', 'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'}, {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}], 'id': '56d4f9902ccc5a1400d833c1', 'question': 'Che cosa ha fatto la misura di sisma?'}, {'answers': [{'answer_st
# ...

# %%
# Directly passing gzips by pointing them in data_files since automatic decompression is supported.
data_files = {"train": "SQuAD_it-train.json.gz", "test": "SQuAD_it-test.json.gz"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# Using custom data configuration default-8aa09e4148418201
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-8aa09e4148418201/0.0.0/c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Loading a remote dataset

# %%
url = "https://github.com/crux82/squad-it/raw/master/"
data_files = {
    "train": url + "SQuAD_it-train.json.gz",
    "test": url + "SQuAD_it-test.json.gz",
}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# Using custom data configuration default-b2375dfabd7ba663
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/7.73M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-b2375dfabd7ba663/0.0.0/c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %% [markdown]
# ## Try it out

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00607/synchronous%20machine.csv'

# %%
# !wget {url}
# Out:
# --2021-11-27 17:58:15--  https://archive.ics.uci.edu/ml/machine-learning-databases/00607/synchronous%20machine.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14569 (14K) [application/x-httpd-php]
# Saving to: ‘synchronous machine.csv’
#
# synchronous machine 100%[===================>]  14.23K  --.-KB/s    in 0.07s
#
# 2021-11-27 17:58:15 (215 KB/s) - ‘synchronous machine.csv’ saved [14569/14569]

# %%
# !mv 'synchronous machine.csv' synchronous_machine.csv

# %%
# !head synchronous_machine.csv
# Out:
# Iy;PF;e;dIf;If
# 3;0,66;0,34;0,383;1,563
# 3;0,68;0,32;0,372;1,552
# 3;0,7;0,3;0,36;1,54
# 3;0,72;0,28;0,338;1,518
# 3;0,74;0,26;0,317;1,497
# 3;0,76;0,24;0,301;1,481
# 3;0,78;0,22;0,29;1,47
# 3;0,8;0,2;0,28;1,46
# 3;0,82;0,18;0,25;1,43

# %%
load_dataset?

# %%
sm = load_dataset('csv', data_files='synchronous_machine.csv', delimiter=';')
# Out:
# Using custom data configuration default-11c505f53b76fba2
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-11c505f53b76fba2/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sm
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Iy', 'PF', 'e', 'dIf', 'If'],
#         num_rows: 557
#     })
# })

# %%
sm_remote = load_dataset('csv', data_files=url, delimiter=';')
# Out:
# Using custom data configuration default-c50a8ada7939d28a
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-c50a8ada7939d28a/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
